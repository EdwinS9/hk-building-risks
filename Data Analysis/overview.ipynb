# %%
import pandas as pd

df = pd.read_csv("DS1_all.csv")
df.head()
# Out:
#    OBJECTID                             DATASET_E  DATASET_C  \
# 0         1  Building information and age records  樓宇資料及樓齡紀錄
# 1         2  Building information and age records  樓宇資料及樓齡紀錄
# 2         3  Building information and age records  樓宇資料及樓齡紀錄
# 3         4  Building information and age records  樓宇資料及樓齡紀錄
# 4         5  Building information and age records  樓宇資料及樓齡紀錄
#
#                                            ADDRESS_E  \
# 0            CHEUNG SHA DD 332 LOT 710 LANTAU ISLAND
# 1            CHEUNG SHA DD 332 LOT 710 LANTAU ISLAND
# 2  DISCOVERY BAY NORTH DEVELOPMENT DISCOVERY BAY ...
# 3               BLK A TUI MIN HOI CLP S4413 SAI KUNG
# 4  PHASES 8 OF A COMMERCIAL DEVELOPMENT DISCOVERY...
#
#                           ADDRESS_C SEARCH1_E SEARCH1_C        SEARCH2_E  \
# 0            大嶼山 長沙丈量約份第332約第710號地段   Islands       離島區  New Territories
# 1            大嶼山 長沙丈量約份第332約第710號地段   Islands       離島區  New Territories
# 2                大嶼山愉景灣第CX1333號短期租約   Islands       離島區  New Territories
# 3               對面海第S4413號官地租用許可證 A  Sai Kung        西貢  New Territories
# 4  大嶼山 愉景灣北 丈量約份第352約第385號地段餘段及增批地段   Islands       離島區  New Territories
#
#   SEARCH2_C  NSEARCH1_E  ...  NSEARCH3_E  NSEARCH3_C NSEARCH4_E NSEARCH4_C  \
# 0        新界     5216949  ...  1984-05-03  1984-05-03      Tower          座
# 1        新界     5216950  ...  1984-05-03  1984-05-03      Tower          座
# 2        新界     5240508  ...  2000-04-14  2000-04-14      Tower          座
# 3        新界     5250757  ...  1966-06-03  1966-06-03      Tower          座
# 4        新界     5426243  ...  2009-09-01  2009-09-01      Tower          座
#
#               NSEARCH5_E NSEARCH5_C   LATITUDE   LONGITUDE GeometryLongitude  \
# 0  Residential/Composite    住宅/綜合用途  22.236231  113.961824        113.961824
# 1  Residential/Composite    住宅/綜合用途  22.236131  113.961770        113.961770
# 2                 Others         其他  22.310561  113.999111        113.999111
# 3  Residential/Composite    住宅/綜合用途  22.376112  114.272736        114.272736
# 4      Office/Commercial     寫字樓/商業  22.308115  114.017211        114.017211
#
#    GeometryLatitude
# 0         22.236231
# 1         22.236131
# 2         22.310561
# 3         22.376112
# 4         22.308115
#
# [5 rows x 23 columns]

# %%
import plotly.express as px

df["completion_date"] = pd.to_datetime(df["NSEARCH3_E"], errors="coerce")
df["age"] = (pd.Timestamp.today() - df["completion_date"]).dt.days / 365.25

fig = px.histogram(df, x="age", nbins=50, title="Distribution of Building Age",
                   labels={"age": "Building Age (years)"})
fig.show()

# %%
import plotly.graph_objects as go
import pandas as pd

ds2 = pd.read_csv("DS2_inspection.csv")
ds2_age = ds2.merge(df[["OBJECTID", "age"]], on="OBJECTID", how="inner")["age"].dropna()
ds1_age = df["age"].dropna()

fig = go.Figure()
for ages, name, color in [
    (ds1_age, "DS1 – all buildings", "steelblue"),
    (ds2_age, "DS2 – noticed buildings", "tomato"),
]:
    fig.add_trace(go.Histogram(
        x=ages, nbinsx=50, name=name,
        histnorm="probability density",
        marker_color=color, opacity=0.6,
    ))

fig.update_layout(
    barmode="overlay",
    title="Age distribution: DS1 vs DS2 (density-normalised)",
    xaxis_title="Building Age (years)",
    yaxis_title="Density",
    legend=dict(x=0.01, y=0.99),
)
fig.show()

# %%
df2 = pd.read_csv("DS2_inspection.csv")
df2.head()
